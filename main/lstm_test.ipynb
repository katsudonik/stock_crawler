# %%
import lstm
ls=lstm.Lstm()
ls.run()
# Out:
# Using TensorFlow backend.
# 2007
# /home/vcp/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/keras/models.py:826: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Epoch 1/100
# 185/185 [==============================] - 1s - loss: 93.7276
# Epoch 2/100
# 185/185 [==============================] - 1s - loss: 74.3256
# Epoch 3/100
# 185/185 [==============================] - 1s - loss: 74.9395
# Epoch 4/100
# 185/185 [==============================] - 1s - loss: 71.8818
# Epoch 5/100
# 185/185 [==============================] - 1s - loss: 71.8693
# Epoch 6/100
# 185/185 [==============================] - 2s - loss: 67.6700
# Epoch 7/100
# 185/185 [==============================] - 1s - loss: 63.1531
# Epoch 8/100
# 185/185 [==============================] - 1s - loss: 63.2302
# Epoch 9/100
# 185/185 [==============================] - 2s - loss: 62.4008
# Epoch 10/100
# ...
