# %%
import lstm
ls=lstm.Lstm('stocks/2371-T')
ls.run()
# Out:
# Using TensorFlow backend.
# /home/vcp/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/keras/models.py:826: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Epoch 1/100
# 180/180 [==============================] - 6s - loss: 119.1814
# Epoch 2/100
# 180/180 [==============================] - 2s - loss: 80.8513
# Epoch 3/100
# 180/180 [==============================] - 2s - loss: 79.7605
# Epoch 4/100
# 180/180 [==============================] - 3s - loss: 75.4321
# Epoch 5/100
# 180/180 [==============================] - 2s - loss: 69.0342
# Epoch 6/100
# 180/180 [==============================] - 2s - loss: 65.2913
# Epoch 7/100
# 180/180 [==============================] - 4s - loss: 64.1552
# Epoch 8/100
# 180/180 [==============================] - 2s - loss: 65.6025
# Epoch 9/100
# 180/180 [==============================] - 4s - loss: 55.0642
# Epoch 10/100
# ...
